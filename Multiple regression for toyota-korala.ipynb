# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
#Read the data
cars = pd.read_csv("E:\data science\class notebook\Toyoto_Corrola.csv")
cars.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3  ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#       KM  HP  Doors  Cylinders  Gears  Weight
# 0  46986  90      3          4      5    1165
# 1  72937  90      3          4      5    1165
# 2  41711  90      3          4      5    1165
# 3  48000  90      3          4      5    1165
# 4  38500  90      3          4      5    1170

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         1436 non-null   int64
#  1   Model      1436 non-null   object
#  2   Price      1436 non-null   int64
#  3   Age_08_04  1436 non-null   int64
#  4   KM         1436 non-null   int64
#  5   HP         1436 non-null   int64
#  6   Doors      1436 non-null   int64
#  7   Cylinders  1436 non-null   int64
#  8   Gears      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 112.3+ KB

# %%
#check for missing values
cars.isna().sum()
# Out:
# Id           0
# Model        0
# Price        0
# Age_08_04    0
# KM           0
# HP           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
cars.drop(["Id","Model"],inplace=True,axis = 1)

# %%
cars.head()
# Out:
#    Price  Age_08_04     KM  HP  Doors  Cylinders  Gears  Weight
# 0  13500         23  46986  90      3          4      5    1165
# 1  13750         23  72937  90      3          4      5    1165
# 2  13950         24  41711  90      3          4      5    1165
# 3  14950         26  48000  90      3          4      5    1165
# 4  13750         30  38500  90      3          4      5    1170

# %%
cars.corr()
# Out:
#               Price  Age_08_04        KM        HP     Doors  Cylinders  \
# Price      1.000000  -0.876590 -0.569960  0.314990  0.185326        NaN
# Age_08_04 -0.876590   1.000000  0.505672 -0.156622 -0.148359        NaN
# KM        -0.569960   0.505672  1.000000 -0.333538 -0.036197        NaN
# HP         0.314990  -0.156622 -0.333538  1.000000  0.092424        NaN
# Doors      0.185326  -0.148359 -0.036197  0.092424  1.000000        NaN
# Cylinders       NaN        NaN       NaN       NaN       NaN        NaN
# Gears      0.063104  -0.005364  0.015023  0.209477 -0.160141        NaN
# Weight     0.581198  -0.470253 -0.028598  0.089614  0.302618        NaN
#
#               Gears    Weight
# Price      0.063104  0.581198
# Age_08_04 -0.005364 -0.470253
# KM         0.015023 -0.028598
# HP         0.209477  0.089614
# Doors     -0.160141  0.302618
# Cylinders       NaN       NaN
# Gears      1.000000  0.020613
# Weight     0.020613  1.000000

# %%
#Format the plot background and scatter plots for all the variables
sns.set_style(style='darkgrid')
sns.pairplot(cars)

# %%
#Build model
import statsmodels.formula.api as smf 
model = smf.ols('Price~Age_08_04+KM+HP+Doors+Cylinders+Gears+Weight',data=cars).fit()

# %%
model.params
# Out:
# Intercept    -410.845504
# Age_08_04    -122.242218
# KM             -0.019994
# HP             28.350149
# Doors          -9.680229
# Cylinders   -1643.382016
# Gears         622.282925
# Weight         18.609651
# dtype: float64

# %%
#t and p-Values
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept    -5.323309
# Age_08_04   -46.728942
# KM          -16.542560
# HP           10.842418
# Doors        -0.242055
# Cylinders    -5.323309
# Gears         3.152234
# Weight       22.446903
# dtype: float64
#  Intercept     1.181900e-07
# Age_08_04    4.387432e-290
# KM            2.238900e-56
# HP            2.231791e-26
# Doors         8.087723e-01
# Cylinders     1.181900e-07
# Gears         1.653931e-03
# Weight        7.856458e-96
# dtype: float64

# %%
#R squared values
(model.rsquared,model.rsquared_adj)
# Out:
# (0.8628024511073656, 0.8622263942190831)

# %%
ml_v=smf.ols('Price~Age_08_04',data = cars).fit()  
#t and p-Values
print(ml_v.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept    138.907847
# Age_08_04    -68.978267
# dtype: float64
#  Intercept    0.0
# Age_08_04    0.0
# dtype: float64

# %%
ml_v=smf.ols('Price~KM',data = cars).fit()  
#t and p-Values
print(ml_v.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept    88.510378
# KM          -26.267601
# dtype: float64
#  Intercept     0.000000e+00
# KM           1.757913e-124
# dtype: float64

# %%
ml_v=smf.ols('Price~HP',data = cars).fit()  
#t and p-Values
print(ml_v.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept     4.803134
# HP           12.567862
# dtype: float64
#  Intercept    1.725695e-06
# HP           1.926234e-34
# dtype: float64

# %%
ml_v=smf.ols('Price~Doors',data = cars).fit()  
#t and p-Values
print(ml_v.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept    19.258097
# Doors         7.141657
# dtype: float64
#  Intercept    1.094732e-73
# Doors        1.461237e-12
# dtype: float64

# %%
ml_v=smf.ols('Price~Cylinders',data = cars).fit()  
#t and p-Values
print(ml_v.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept    112.115846
# Cylinders    112.115846
# dtype: float64
#  Intercept    0.0
# Cylinders    0.0
# dtype: float64

# %%
ml_v=smf.ols('Price~Gears',data = cars).fit()  
#t and p-Values
print(ml_v.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept    1.814534
# Gears        2.394401
# dtype: float64
#  Intercept    0.069804
# Gears        0.016775
# dtype: float64

# %%
ml_v=smf.ols('Price~Weight',data = cars).fit()  
#t and p-Values
print(ml_v.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept   -20.263590
# Weight       27.045855
# dtype: float64
#  Intercept     1.739508e-80
# Weight       1.630487e-130
# dtype: float64

# %%
rsq_Age_08_04  = smf.ols('Age_08_04~KM+HP+Doors+Cylinders+Gears+Weight',data=cars).fit().rsquared  
vif_Age_08_04  = 1/(1-rsq_Age_08_04) # 16.33

rsq_HP  = smf.ols('HP~Age_08_04+KM+Doors+Cylinders+Gears+Weight',data=cars).fit().rsquared  
vif_HP  = 1/(1-rsq_HP)

rsq_KM = smf.ols('KM~Age_08_04+HP+Doors+Cylinders+Gears+Weight',data=cars).fit().rsquared  
vif_KM = 1/(1-rsq_KM) # 564.98

rsq_Doors = smf.ols('Doors~KM+Age_08_04+HP+Cylinders+Gears+Weight',data=cars).fit().rsquared  
vif_Doors = 1/(1-rsq_Doors) #  564.84

rsq_Cylinders = smf.ols('Cylinders~KM+Age_08_04+HP+Doors+Gears+Weight',data=cars).fit().rsquared  
vif_Cylinders = 1/(1-rsq_Cylinders) #  16.35

rsq_Gears = smf.ols('Gears~KM+Age_08_04+HP+Doors+Cylinders+Weight',data=cars).fit().rsquared  
vif_Gears = 1/(1-rsq_Gears ) #  16.35

rsq_Weight= smf.ols('Weight~KM+Age_08_04+HP+Doors+Cylinders+Gears',data=cars).fit().rsquared  
vif_Weight = 1/(1-rsq_Weight) #  16.35

# Storing vif values in a data frame
d1 = {'Variables':['Age_08_04','KM','HP','Doors','Cylinders','Gears','Weight'],'VIF':[vif_Age_08_04,vif_KM,vif_HP,vif_Doors,vif_Cylinders,vif_Gears,vif_Weight]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
# E:\python\lib\site-packages\statsmodels\regression\linear_model.py:1685: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#    Variables       VIF
# 0  Age_08_04  1.874542
# 1         KM  1.627039
# 2         HP  1.214909
# 3      Doors  1.149301
# 4  Cylinders  0.000000
# 5      Gears  1.096501
# 6     Weight  1.508041

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>5000)) # the point which are not on stright line
# Out:
# [array([109, 147, 523], dtype=int64)]

# %%
list(np.where(model.resid<-5000)) # why 10
# Out:
# [array([191, 192, 221, 601, 960], dtype=int64)]

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Age_08_04", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Age_08_04", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "KM", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "HP", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Doors", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model,"Cylinders",fig=fig)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-ced8ef866555> in <module>
#       1 fig = plt.figure(figsize=(15,8))
# ----> 2 fig = sm.graphics.plot_regress_exog(model,"Cylinders",fig=fig)
#       3 plt.show()
#
# E:\python\lib\site-packages\statsmodels\graphics\regressionplots.py in plot_regress_exog(results, exog_idx, fig)
#     257
#     258     ax = fig.add_subplot(2, 2, 4)
# --> 259     fig = plot_ccpr(results, exog_idx, ax=ax)
#     260     ax.set_title('CCPR Plot', fontsize='large')
#     261     #ax.set_xlabel(exog_name)
#
# E:\python\lib\site-packages\statsmodels\graphics\regressionplots.py in plot_ccpr(results, exog_idx, ax)
#     639     mod = OLS(x1beta, add_constant(x1)).fit()
#     640     params = mod.params
# --> 641     fig = abline_plot(*params, **dict(ax=ax))
#     642     #ax.plot(x1, x1beta, '-')
# ...

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Gears", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Weight", fig=fig)
plt.show()

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(cars)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()
# Out:
# E:\python\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#index and value of influencer where c is more than .5
(np.argmax(c),np.max(c))
# Out:
# (221, 0.8359007508852095)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = cars.shape[1]
n = cars.shape[0]
leverage_cutoff = 3*((k + 1)/n)

# %%
cars[cars.index.isin([221, 960])]
# Out:
#      Price  Age_08_04     KM   HP  Doors  Cylinders  Gears  Weight
# 221  12450         44  74172  110      5          4      5    1615
# 960   9390         66  50806   86      3          4      5    1480

# %%
#See the differences in HP and other variable values
cars.head()
# Out:
#    Price  Age_08_04     KM  HP  Doors  Cylinders  Gears  Weight
# 0  13500         23  46986  90      3          4      5    1165
# 1  13750         23  72937  90      3          4      5    1165
# 2  13950         24  41711  90      3          4      5    1165
# 3  14950         26  48000  90      3          4      5    1165
# 4  13750         30  38500  90      3          4      5    1170

# %%
#Load the data
cars_new = pd.read_csv("E:\data science\class notebook\Toyoto_Corrola.csv")

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())
car1=cars_new.drop(cars_new.index[[221,960]],axis=0).reset_index()

# %%
#Drop the original index
car1=car1.drop(['index'],axis=1)

# %%
car1
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3     ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1429  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1430  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1431  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1432  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1433  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04     KM   HP  Doors  Cylinders  Gears  Weight
# 0            23  46986   90      3          4      5    1165
# ...

# %%
final_ml_V= smf.ols('Price~Age_08_04+KM+HP+Cylinders+Gears+Weight',data = car1).fit()

# %%
(final_ml_V.rsquared,final_ml_V.aic)
# Out:
# (0.8726263626033617, 24633.77225172694)

# %%
final_ml_V= smf.ols('Price~Age_08_04+KM+HP+Doors+Gears+Weight',data = car1).fit()

# %%
(final_ml_V.rsquared,final_ml_V.aic)
# Out:
# (0.8728201848607586, 24633.588496856977)

# %%
model_influence_V = final_ml_V.get_influence()
(c_V, _) = model_influence_V.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(car1)),np.round(c_V,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');
# Out:
# E:\python\lib\site-packages\ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
#Check the accuracy of the mode
final_ml_V= smf.ols('Price~Age_08_04+KM+HP+Doors+Gears+Weight',data = car1).fit()

# %%
(final_ml_V.rsquared,final_ml_V.aic)
# Out:
# (0.8728201848607586, 24633.588496856977)

# %%
new_data=pd.DataFrame({'Age_08_04':72,"KM":38500,"HP":95,"Doors":4,"Gears":5,"Weight":1115},index=[1])

# %%
final_ml_V.predict(new_data)
# Out:
# 1    10300.064301
# dtype: float64

# %%
final_ml_V.predict(cars_new.iloc[0:5,])   # new prediction of Y for first 5 rows
# Out:
# 0    16845.895540
# 1    16284.225530
# 2    16844.069819
# 3    16475.963779
# 4    16330.059996
# dtype: float64

# %%
pred_y = final_ml_V.predict(cars_new)

# %%
pred_y
# Out:
# 0       16845.895540
# 1       16284.225530
# 2       16844.069819
# 3       16475.963779
# 4       16330.059996
#             ...
# 1431     8824.533880
# 1432     8285.039160
# 1433     8443.974918
# 1434     8562.134356
# 1435    10998.006839
# Length: 1436, dtype: float64
